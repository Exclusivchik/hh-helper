# %%
import pandas as pd

# %%
df = pd.read_csv("data/vacancies_labeled_ml_dl.csv")
df.head()
# Out:
#    vacancy_id                      vacancy_url  \
# 0   131765894  https://hh.ru/vacancy/131765894
# 1   130285387  https://hh.ru/vacancy/130285387
# 2   128539097  https://hh.ru/vacancy/128539097
# 3   131619736  https://hh.ru/vacancy/131619736
# 4   131478467  https://hh.ru/vacancy/131478467
#
#                             salary   region  year_published  \
# 0               от 1200000 KZT net   Алматы            2026
# 1              от 150000 RUR gross  Воронеж            2026
# 2                              NaN   Москва            2026
# 3  от 15000000 до 15000000 UZS net  Ташкент            2026
# 4                              NaN   Москва            2026
#
#                                         vacancy_text ml_dl_label  \
# 0  ML-инженер / Machine Learning Engineer MINISO ...    точно да
# 1  Инженер компьютерного зрения / Machine Learnin...    точно да
# 2  Machine Learning Engineer (RecSys, E-com) GRI ...    точно да
# ...

# %%
df_ml = df[df["ml_dl_label"] !="точно нет"]

# %%
df_ml.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2307 entries, 0 to 11368
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   vacancy_id      2307 non-null   int64
#  1   vacancy_url     2307 non-null   str
#  2   salary          635 non-null    str
#  3   region          2307 non-null   str
#  4   year_published  2307 non-null   int64
#  5   vacancy_text    2307 non-null   str
#  6   ml_dl_label     2307 non-null   str
#  7   ml_dl_binary    2307 non-null   int64
#  8   confidence      2307 non-null   str
#  9   reason          2307 non-null   str
# dtypes: int64(3), str(7)
# memory usage: 198.3 KB

# %%
df_ml.columns
# Out:
# Index(['vacancy_id', 'vacancy_url', 'salary', 'region', 'year_published',
#        'vacancy_text', 'ml_dl_label', 'ml_dl_binary', 'confidence', 'reason'],
#       dtype='str')

# %%
df_ml["vacancy_id"].to_csv("id_ml_dl.csv")
